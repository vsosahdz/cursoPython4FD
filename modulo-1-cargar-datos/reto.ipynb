# %% [markdown]
# # Reto — Módulo 1: Cargar y ver datos 📂
#
# **Taller Python for Ford 2026**
#
# Resuelve cada ejercicio escribiendo tu código donde dice `# <-- TU CÓDIGO`.
# Luego ejecuta la celda de **autocomprobación** para ver si acertaste (✅).
#
# > 💡 Repasa `guia.ipynb` del módulo si te atoras.

# %% [markdown]
# ## Preparación
# Ejecuta estas dos celdas antes de empezar.

# %%
import pandas as pd

# %%
# Ejecuta esta celda primero. Define la funcion de autocomprobacion.
def revisar(condicion, mensaje_ok, mensaje_error):
    """Muestra un exito si acertaste, o detiene con una pista si no."""
    assert condicion, "X  " + mensaje_error
    print("OK  " + mensaje_ok)

# %% [markdown]
# ### Ejercicio 1 — Cargar `ventas.csv`
# Carga el archivo `../datos/ventas.csv` en una variable llamada `ventas`.
# Luego guarda en `num_filas` **cuántas filas** tiene (pista: `.shape`).

# %%
ventas = ...   # <-- TU CÓDIGO: carga el CSV
num_filas = ...  # <-- TU CÓDIGO: número de filas

# %% [markdown]
# **Autocomprobación** 👇

# %%
revisar(num_filas == 5000,
        "¡Correcto! La tabla tiene 5000 ventas.",
        "num_filas debería ser 5000. Usa ventas.shape[0].")

# %% [markdown]
# ### Ejercicio 2 — ¿Cuántas columnas?
# Guarda en `num_columnas` el número de columnas de `ventas` (pista: `.shape`).

# %%
num_columnas = ...  # <-- TU CÓDIGO

# %% [markdown]
# **Autocomprobación** 👇

# %%
revisar(num_columnas == 11,
        "¡Bien! Son 11 columnas.",
        "num_columnas debería ser 11. Usa ventas.shape[1].")

# %% [markdown]
# ### Ejercicio 3 — Cargar los concesionarios
# Carga `../datos/concesionarios.csv` en `concesionarios` y guarda en
# `num_concesionarios` cuántas filas tiene.

# %%
concesionarios = ...   # <-- TU CÓDIGO
num_concesionarios = ...  # <-- TU CÓDIGO

# %% [markdown]
# **Autocomprobación** 👇

# %%
revisar(num_concesionarios == 20,
        "¡Correcto! Hay 20 concesionarios.",
        "Deberían ser 20. Revisa la carga del CSV.")

# %% [markdown]
# ## ¿Terminaste?
# Si todas las autocomprobaciones muestran ✅, ¡lo lograste!
# Si alguna falla, lee la pista y vuelve a intentar. Las **soluciones** se
# liberan después. ¡Nos vemos en la sesión de dudas! 🙌
