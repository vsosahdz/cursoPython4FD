# %% [markdown]
# # Reto — Módulo 3: Filtrar y agrupar 🔍📊
#
# **Taller Python for Ford 2026**
#
# Aplica filtros, `groupby` y `merge`. Comprueba cada respuesta con su celda ✅.

# %% [markdown]
# ## Preparación
# Ejecuta estas dos celdas antes de empezar.

# %%
import pandas as pd
ventas = pd.read_csv("../datos/ventas.csv")
concesionarios = pd.read_csv("../datos/concesionarios.csv")

# %%
# Ejecuta esta celda primero. Define la funcion de autocomprobacion.
def revisar(condicion, mensaje_ok, mensaje_error):
    """Muestra un exito si acertaste, o detiene con una pista si no."""
    assert condicion, "X  " + mensaje_error
    print("OK  " + mensaje_ok)

# %% [markdown]
# ### Ejercicio 1 — Filtrar por modelo
# Guarda en `n_f150` **cuántas ventas** son del modelo `F-150`.

# %%
n_f150 = ...  # <-- TU CÓDIGO

# %% [markdown]
# **Autocomprobación** 👇

# %%
revisar(n_f150 == 1258,
        "¡Correcto! 1258 ventas de F-150.",
        "Deberían ser 1258. Filtra modelo == 'F-150' y usa .shape[0].")

# %% [markdown]
# ### Ejercicio 2 — Agrupar y sumar
# Usa `groupby` para sumar las `unidades` por modelo, y guarda en
# `unidades_explorer` el total de unidades del modelo `Explorer`.

# %%
por_modelo = ...      # <-- TU CÓDIGO: groupby de unidades por modelo
unidades_explorer = ...  # <-- TU CÓDIGO: valor de Explorer

# %% [markdown]
# **Autocomprobación** 👇

# %%
revisar(unidades_explorer == 2054,
        "¡Bien! 2054 unidades de Explorer.",
        "Deberían ser 2054. Revisa el groupby de unidades por modelo.")

# %% [markdown]
# ### Ejercicio 3 — Combinar tablas (merge) y agrupar por región
# Une `ventas` con `concesionarios` por `id_concesionario`. Luego guarda en
# `total_sureste` el **total de `monto_venta`** de la región `Sureste`.

# %%
completa = ...       # <-- TU CÓDIGO: merge de las dos tablas
total_sureste = ...  # <-- TU CÓDIGO: total de monto_venta en Sureste

# %% [markdown]
# **Autocomprobación** 👇

# %%
revisar(total_sureste == 2397041460,
        "¡Excelente! Dominas merge + filtro + suma.",
        "Revisa el merge por id_concesionario y el filtro region == 'Sureste'.")

# %% [markdown]
# ## ¿Terminaste?
# Si todas las autocomprobaciones muestran ✅, ¡lo lograste!
# Si alguna falla, lee la pista y vuelve a intentar. Las **soluciones** se
# liberan después. ¡Nos vemos en la sesión de dudas! 🙌
