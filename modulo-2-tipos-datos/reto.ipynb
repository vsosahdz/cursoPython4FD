# %% [markdown]
# # Reto — Módulo 2: Tipos de datos 🔢🔤📅
#
# **Taller Python for Ford 2026**
#
# Escribe tu código donde dice `# <-- TU CÓDIGO` y comprueba con la celda de autocomprobación.

# %% [markdown]
# ## Preparación
# Ejecuta estas dos celdas antes de empezar.

# %%
import pandas as pd
ventas = pd.read_csv("../datos/ventas.csv")

# %%
# Ejecuta esta celda primero. Define la funcion de autocomprobacion.
def revisar(condicion, mensaje_ok, mensaje_error):
    """Muestra un exito si acertaste, o detiene con una pista si no."""
    assert condicion, "X  " + mensaje_error
    print("OK  " + mensaje_ok)

# %% [markdown]
# ### Ejercicio 1 — Modelos distintos
# Guarda en `n_modelos` **cuántos modelos distintos** hay en la columna `modelo`
# (pista: `.nunique()`).

# %%
n_modelos = ...  # <-- TU CÓDIGO

# %% [markdown]
# **Autocomprobación** 👇

# %%
revisar(n_modelos == 6,
        "¡Correcto! Hay 6 modelos.",
        "Deberían ser 6. Usa ventas['modelo'].nunique().")

# %% [markdown]
# ### Ejercicio 2 — Convertir la fecha y sacar el año
# Convierte la columna `fecha` a tipo fecha con `pd.to_datetime`.
# Luego guarda en `anio_min` el **año más antiguo** (pista: `.dt.year.min()`).

# %%
ventas["fecha"] = ...  # <-- TU CÓDIGO: convertir a fecha
anio_min = ...        # <-- TU CÓDIGO: año mínimo

# %% [markdown]
# **Autocomprobación** 👇

# %%
revisar(anio_min == 2024,
        "¡Bien! Los datos empiezan en 2024.",
        "anio_min debería ser 2024. Revisa .dt.year.min().")

# %% [markdown]
# ### Ejercicio 3 — Conteo por categoría
# Guarda en `n_financiamiento` **cuántas ventas** fueron con método de pago
# `Financiamiento` (pista: un filtro y `.sum()`, o `value_counts()`).

# %%
n_financiamiento = ...  # <-- TU CÓDIGO

# %% [markdown]
# **Autocomprobación** 👇

# %%
revisar(n_financiamiento == 2487,
        "¡Correcto! 2487 ventas a financiamiento.",
        "Deberían ser 2487. Filtra metodo_pago == 'Financiamiento'.")

# %% [markdown]
# ## ¿Terminaste?
# Si todas las autocomprobaciones muestran ✅, ¡lo lograste!
# Si alguna falla, lee la pista y vuelve a intentar. Las **soluciones** se
# liberan después. ¡Nos vemos en la sesión de dudas! 🙌
